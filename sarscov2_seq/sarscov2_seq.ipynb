# %% [markdown]
# # Align paired-end read with SARS-CoV-2 genome (NC_045512)
#
# ## Index FASTA file using bowtie2
# ```
# mkdir bowtie2
# bowtie2-build NC_045512.fa bowtie2/NC_045512
# ```
#
# ## Align FASTQ reads using bowtie2
# ```
# bowtie2 -t -x bowtie2/NC_045512 -1 SarsCov2Million_S1_L001_R1_001.fastq.gz -2 SarsCov2Million_S1_L001_R2_001.fastq.gz -S bowtie2/SarsCov2
# Million.sam
# ```
